# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhrecharla/CODSOFT/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 - MOVIE GENRE CLASSIFICATION

# %% [markdown]
# create a machine Learning model that can predict the genre of a movie
# based on its plot summary or other textual information.
# you can use techniques like TF-IDF or word embeddings with classifiers such as
# Naive Bayes, Logistic Regression, or Support Vector Machines.

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'test_data_solution.txt',
#  'description.txt',
#  'test_data.txt',
#  'train_data.txt',
#  'sample_data']

# %% [markdown]
# 1. Read or Extract data

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data =  pd.read_csv("/content/description.txt")
data
# Out:
#                                          Train data:
# 0             ID ::: TITLE ::: GENRE ::: DESCRIPTION
# 1             ID ::: TITLE ::: GENRE ::: DESCRIPTION
# 2             ID ::: TITLE ::: GENRE ::: DESCRIPTION
# 3             ID ::: TITLE ::: GENRE ::: DESCRIPTION
# 4                                         Test data:
# 5                       ID ::: TITLE ::: DESCRIPTION
# 6                       ID ::: TITLE ::: DESCRIPTION
# 7                       ID ::: TITLE ::: DESCRIPTION
# 8                       ID ::: TITLE ::: DESCRIPTION
# 9                                            Source:
# 10  ftp://ftp.fu-berlin.de/pub/misc/movies/database/

# %% [markdown]
# 2. Create and apply FUnction to read data by splitting by ":::"

# %%
def load_data(file_path):
  with open(file_path, 'r', encoding='utf-8') as f:
    data = f.readlines()
    data = [line.strip().split(':::') for line in data]
  return data

# %%
train_data = load_data("/content/train_data.txt")
train_df = pd.DataFrame(train_data, columns=["id", "title", "genre", "description"])

test_data = load_data("/content/test_data.txt")
test_df = pd.DataFrame(test_data, columns=["id", "title", "description"])

test_solution = load_data("/content/test_data_solution.txt")
test_solution_df = pd.DataFrame(test_solution, columns=["id", "title", "genre" , "Description"])

# %%
print("train data: ")
train_df
# Out:
# train data:
#          id                                            title          genre  \
# 0        1                     Oscar et la dame rose (2009)          drama
# 1        2                                     Cupid (1997)       thriller
# 2        3                 Young, Wild and Wonderful (1980)          adult
# 3        4                            The Secret Sin (1915)          drama
# 4        5                           The Unrecovered (2007)          drama
# ...     ...                                              ...            ...
# 7930  7931    Fierce Light: When Spirit Meets Action (2008)    documentary
# 7931  7932                      Le temple des phénix (2012)    documentary
# 7932  7933                    "Craigslist Therapist" (2016)         comedy
# 7933  7934             I diafanoidi vengono da Marte (1966)         sci-fi
# 7934  7935                        A Masculine Ending (1992)        mystery
#
#                                             description
# 0      Listening in to a conversation between his do...
# 1      A brother and sister with a past incestuous r...
# 2      As the bus empties the students for their fie...
# 3      To help their unemployed father make ends mee...
# 4      The film's title refers not only to the un-re...
# ...                                                 ...
# 7930   Fueled by the belief that another world is po...
# 7931   Around the Masaya Volcano in Nicaragua, life ...
# 7932   Facing a divorce and financial ruin, Steven W...
# 7933   In the 21st century, aliens (weird, green, li...
# 7934   While English professor Loretta Lawson is att...
#
# [7935 rows x 4 columns]

# %%
print("\nTest data: ")
test_df
# Out:
# Test data:
#          id                                           title  \
# 0        1                            Edgar's Lunch (1998)
# 1        2                        La guerra de papá (1977)
# 2        3                     Off the Beaten Track (2010)
# 3        4                          Meu Amigo Hindu (2015)
# 4        5                               Er nu zhai (1955)
# ...     ...                                             ...
# 8206  8207                 You Can Draw 'Star Wars' (2007)
# 8207  8208               La mano che nutre la morte (1974)
# 8208  8209                           Weak at Denise (1999)
# 8209  8210                              Lost Legacy (2013)
# 8210  8211    J. Cole Forest Hills Drive Homecoming (2016)
#
#                                             description
# 0      L.R. Brane loves his life - his car, his apar...
# 1      Spain, March 1964: Quico is a very naughty ch...
# 2      One year in the life of Albin and his family ...
# 3      His father has died, he hasn't spoken with hi...
# 4      Before he was known internationally as a mart...
# ...                                                 ...
# 8206   STAR WARS artist Matt Busch takes you through...
# 8207   Baron Ivan Rassimov, a brilliant doctor, died...
# 8208   In this suburban black comedy, bachelor Colin...
# 8209   Feature-documentary film about a prominent Ar...
# 8210                                      Hip-hop super
#
# [8211 rows x 3 columns]

# %%
print("\nTest solution:")
test_solution_df
# Out:
# Test solution:
#          id                                              title          genre  \
# 0        1                               Edgar's Lunch (1998)       thriller
# 1        2                           La guerra de papá (1977)         comedy
# 2        3                        Off the Beaten Track (2010)    documentary
# 3        4                             Meu Amigo Hindu (2015)          drama
# 4        5                                  Er nu zhai (1955)          drama
# ...     ...                                                ...            ...
# 8050  8051                 Andre Rieu: Happy Birthday! (2013)          music
# 8051  8052                             "House of Bond" (2017)          drama
# 8052  8053                      4 a.m.: Open All Night (1999)          short
# 8053  8054    Ring of Honor Winter Warriors Tour: Duluth (2...         sport
# 8054  8055                                  "landlord" (2017)         comedy
#
#                                             Description
# 0      L.R. Brane loves his life - his car, his apar...
# 1      Spain, March 1964: Quico is a very naughty ch...
# 2      One year in the life of Albin and his family ...
# 3      His father has died, he hasn't spoken with hi...
# 4      Before he was known internationally as a mart...
# ...                                                 ...
# 8050   It always gives me great pleasure to host our...
# 8051   House of Bond tells the rags-to-riches-to-rag...
# 8052   It's almost 4 a.m., and three people are in a...
# 8053   JANUARY 23RD, 2016 INFINITE ENERGY CENTER DUL...
# 8054   This absurdist comedy takes place in a small ...
#
# [8055 rows x 4 columns]

# %% [markdown]
# 3. Feature extraction : TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features = 10000)

X_train_tfidf = vectorizer.fit_transform(train_df["description"])
X_test_tfidf = vectorizer.transform(test_df["description"])

print(f"Training data shape: {X_train_tfidf.shape}")
print(f"Testing data shape: {X_test_tfidf.shape}")
# Out:
# Training data shape: (7935, 10000)
# Testing data shape: (8211, 10000)

# %% [markdown]
# 4. Encoding the Target labels

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df["genre"])
print(f"unique genres in the training data: {label_encoder.classes_}")
# Out:
# unique genres in the training data: [' action ' ' adult ' ' adventure ' ' animation ' ' biography ' ' comedy '
#  ' crime ' ' documentary ' ' drama ' ' family ' ' fantasy ' ' game-show '
#  ' history ' ' horror ' ' music ' ' musical ' ' mystery ' ' news '
#  ' reality-tv ' ' romance ' ' sci-fi ' ' short ' ' sport ' ' talk-show '
#  ' thriller ' ' war ' ' western ']

# %% [markdown]
# 5. Model Building - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(max_iter=200)
lr_model.fit(X_train_tfidf, y_train)

y_pred = lr_model.predict(X_test_tfidf)
predicted_genres = label_encoder.inverse_transform(y_pred)

test_df["predicted_genre"] = predicted_genres
test_df[["title", "predicted_genre"]]
# Out:
#                                                title predicted_genre
# 0                              Edgar's Lunch (1998)           drama
# 1                          La guerra de papá (1977)           drama
# 2                       Off the Beaten Track (2010)     documentary
# 3                            Meu Amigo Hindu (2015)           drama
# 4                                 Er nu zhai (1955)           drama
# ...                                              ...             ...
# 8206                You Can Draw 'Star Wars' (2007)          comedy
# 8207              La mano che nutre la morte (1974)           drama
# 8208                          Weak at Denise (1999)          comedy
# 8209                             Lost Legacy (2013)     documentary
# 8210   J. Cole Forest Hills Drive Homecoming (2016)     documentary
#
# [8211 rows x 2 columns]

# %%
test_df["predicted_genre"] = predicted_genres

merged_df = pd.merge(test_solution_df[["id", "genre"]], test_df[["id", "predicted_genre"]], on ="id")
merged_df
# Out:
#          id          genre predicted_genre
# 0        1       thriller           drama
# 1        2         comedy           drama
# 2        3    documentary     documentary
# 3        4          drama           drama
# 4        5          drama           drama
# ...     ...            ...             ...
# 8050  8051          music     documentary
# 8051  8052          drama           drama
# 8052  8053          short           short
# 8053  8054          sport           sport
# 8054  8055         comedy           drama
#
# [8055 rows x 3 columns]

# %% [markdown]
# 6. Model Evaluation - Logistic Regression

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(merged_df["genre"], merged_df["predicted_genre"])
print(f"Accuracy: {accuracy:.4f}")

print("\nClassification Report:")
print(classification_report(merged_df["genre"], merged_df["predicted_genre"]))
# Out:
# Accuracy: 0.5140
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       action        1.00      0.02      0.04       201
#        adult        0.00      0.00      0.00        85
#    adventure        0.00      0.00      0.00       101
#    animation        0.00      0.00      0.00        91
#    biography        0.00      0.00      0.00        38
#       comedy        0.45      0.44      0.45      1097
#        crime        0.00      0.00      0.00        56
#  documentary        0.58      0.89      0.70      1943
#        drama        0.47      0.80      0.59      2073
#       family        0.00      0.00      0.00       127
#      fantasy        0.00      0.00      0.00        41
#    game-show        1.00      0.04      0.07        27
#      history        0.00      0.00      0.00        37
#       horror        0.77      0.29      0.42       329
#        music        1.00      0.06      0.11       117
#      musical        0.00      0.00      0.00        32
#      mystery        0.00      0.00      0.00        46
#         news        0.00      0.00      0.00        29
#   reality-tv        0.75      0.02      0.05       128
#      romance        0.00      0.00      0.00       108
#       sci-fi        1.00      0.02      0.04       100
#        short        0.47      0.14      0.22       774
#        sport        0.86      0.11      0.20        54
#    talk-show        0.00      0.00      0.00        50
#     thriller        0.11      0.00      0.01       218
#          war        0.00      0.00      0.00        19
#      western        0.95      0.30      0.45       134
#
#      accuracy                           0.51      8055
#     macro avg       0.35      0.12      0.12      8055
#  weighted avg       0.49      0.51      0.43      8055

# %% [markdown]
# 7. Model Bulding - Navie Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
y_pred_nb = nb_model.predict(X_test_tfidf)
predicted_genres_nb = label_encoder.inverse_transform(y_pred_nb)

test_df["predicted_genre_nb"] = predicted_genres_nb
merged_df_nb = pd.merge(test_solution_df[["id", "genre"]], test_df[["id", "predicted_genre_nb"]], on="id")

# %% [markdown]
# 8. Model Evsluation - Navie Bayes

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy_nb = accuracy_score(merged_df_nb["genre"], merged_df_nb["predicted_genre_nb"])
print(f"navtive Bayes Classification Report: ")

print("Native Bayes Classification Report: ")
print(classification_report(merged_df_nb["genre"], merged_df_nb["predicted_genre_nb"], target_names=label_encoder.classes_))
# Out:
# navtive Bayes Classification Report:
# Native Bayes Classification Report:
#                precision    recall  f1-score   support
#
#       action        0.00      0.00      0.00       201
#        adult        0.00      0.00      0.00        85
#    adventure        0.00      0.00      0.00       101
#    animation        0.00      0.00      0.00        91
#    biography        0.00      0.00      0.00        38
#       comedy        0.57      0.07      0.12      1097
#        crime        0.00      0.00      0.00        56
#  documentary        0.54      0.89      0.67      1943
#        drama        0.38      0.87      0.53      2073
#       family        0.00      0.00      0.00       127
#      fantasy        0.00      0.00      0.00        41
#    game-show        0.00      0.00      0.00        27
#      history        0.00      0.00      0.00        37
#       horror        0.00      0.00      0.00       329
#        music        0.00      0.00      0.00       117
#      musical        0.00      0.00      0.00        32
#      mystery        0.00      0.00      0.00        46
#         news        0.00      0.00      0.00        29
#   reality-tv        0.00      0.00      0.00       128
#      romance        0.00      0.00      0.00       108
#       sci-fi        0.00      0.00      0.00       100
#        short        1.00      0.00      0.00       774
#        sport        0.00      0.00      0.00        54
#    talk-show        0.00      0.00      0.00        50
#     thriller        0.00      0.00      0.00       218
#          war        0.00      0.00      0.00        19
#      western        0.00      0.00      0.00       134
#
#      accuracy                           0.45      8055
#     macro avg       0.09      0.07      0.05      8055
#  weighted avg       0.40      0.45      0.31      8055

# %% [markdown]
# 9. Model Building : SVM(Support Vector Machine)

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel="linear")
svm_model.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_svm = svm_model.predict(X_test_tfidf)
predicted_genres_svm = label_encoder.inverse_transform(y_pred_svm)

test_df["predicted_genre_svm"] = predicted_genres_svm
merged_df_svm = pd.merge(test_solution_df[["id", "genre"]], test_df[["id", "predicted_genre_svm"]], on="id")

# %% [markdown]
# 10. Model Evaluation - SVM (Support Vector Machine )

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy_svm = accuracy_score(merged_df_svm["genre"], merged_df_svm["predicted_genre_svm"])
print(f"SVM Accuracy: {accuracy_svm} ")

print("SVM Classification Report: ")
print(classification_report(merged_df_svm["genre"], merged_df_svm["predicted_genre_svm"], target_names=label_encoder.classes_))
# Out:
# SVM Accuracy: 0.5376784605834886
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#       action        0.69      0.12      0.20       201
#        adult        0.56      0.12      0.19        85
#    adventure        0.60      0.15      0.24       101
#    animation        0.00      0.00      0.00        91
#    biography        0.00      0.00      0.00        38
#       comedy        0.45      0.47      0.46      1097
#        crime        0.00      0.00      0.00        56
#  documentary        0.62      0.85      0.71      1943
#        drama        0.48      0.79      0.60      2073
#       family        0.00      0.00      0.00       127
#      fantasy        0.00      0.00      0.00        41
#    game-show        0.82      0.52      0.64        27
#      history        0.00      0.00      0.00        37
#       horror        0.72      0.48      0.58       329
#        music        0.82      0.23      0.36       117
#      musical        0.00      0.00      0.00        32
#      mystery        0.00      0.00      0.00        46
#         news        0.00      0.00      0.00        29
#   reality-tv        0.65      0.10      0.18       128
#      romance        0.00      0.00      0.00       108
#       sci-fi        0.64      0.14      0.23       100
#        short        0.46      0.19      0.27       774
#        sport        0.77      0.19      0.30        54
#    talk-show        0.50      0.04      0.07        50
#     thriller        0.45      0.06      0.11       218
#          war        0.00      0.00      0.00        19
#      western        0.91      0.56      0.69       134
#
#      accuracy                           0.54      8055
#     macro avg       0.38      0.19      0.22      8055
#  weighted avg       0.51      0.54      0.48      8055

# %% [markdown]
# Test case:

# %%
zoner_Description = [
    "Explosive fight scenes in the city streets",
    "A haunted mansion that traps its visitors",
    "A brave adventurer in search of lost treasure",
    "A forbidden romance in the 1920s",
    "A daring rescue mission with a love interest"
]

test_data_tfidf = vectorizer.transform(zoner_Description)

y_pred_lr = lr_model.predict(test_data_tfidf)
predicted_genres_lr = label_encoder.inverse_transform(y_pred_lr)

y_pred_nb = nb_model.predict(test_data_tfidf)
predicted_genres_nb = label_encoder.inverse_transform(y_pred_nb)

y_pred_svm = svm_model.predict(test_data_tfidf)
predicted_genres_svm = label_encoder.inverse_transform(y_pred_svm)

print("predicted genres using Logistic Regression: ", predicted_genres_lr)
print("predicted genres using Naive Bayes        : ", predicted_genres_nb)
print("predicted genres using SVM                : ", predicted_genres_svm)
print()

for i , message in enumerate(zoner_Description):
  print(f"zoner {i+1}: {message}")
  print(f"Status : \tNative bayes prediction      : {predicted_genres_nb[i]}")
  print(f"\t\tLogistic Regression prediction : {predicted_genres_lr[i]}")
  print(f"\t\tSVM prediction                 : {predicted_genres_svm[i]}")
  print("="*100)
# Out:
# predicted genres using Logistic Regression:  [' documentary ' ' documentary ' ' drama ' ' drama ' ' drama ']
# predicted genres using Naive Bayes        :  [' documentary ' ' documentary ' ' documentary ' ' drama ' ' drama ']
# predicted genres using SVM                :  [' documentary ' ' horror ' ' drama ' ' drama ' ' drama ']
#
# zoner 1: Explosive fight scenes in the city streets
# Status : 	Native bayes prediction      :  documentary
# 		Logistic Regression prediction :  documentary
# 		SVM prediction                 :  documentary
# ====================================================================================================
# zoner 2: A haunted mansion that traps its visitors
# Status : 	Native bayes prediction      :  documentary
# 		Logistic Regression prediction :  documentary
# 		SVM prediction                 :  horror
# ====================================================================================================
# zoner 3: A brave adventurer in search of lost treasure
# Status : 	Native bayes prediction      :  documentary
# 		Logistic Regression prediction :  drama
# 		SVM prediction                 :  drama
# ====================================================================================================
# zoner 4: A forbidden romance in the 1920s
# Status : 	Native bayes prediction      :  drama
# 		Logistic Regression prediction :  drama
# 		SVM prediction                 :  drama
# ====================================================================================================
# zoner 5: A daring rescue mission with a love interest
# Status : 	Native bayes prediction      :  drama
# 		Logistic Regression prediction :  drama
# 		SVM prediction                 :  drama
# ====================================================================================================
